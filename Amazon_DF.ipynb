# %% [markdown]
# # Data Cleaning with Python for Amazon Dataset
#
# In this notebook, I present the process of data cleaning conducted on an Amazon dataset using Python programming language. The dataset contains information pertinent to Amazon's operations and sales. Leveraging the powerful libraries of NumPy and Pandas, I systematically cleaned the data to ensure its accuracy, consistency, and usability for subsequent analysis.
#
# The data cleaning process involved:
#
# 1. **Data Inspection:** Initial exploration and examination of the dataset to identify inconsistencies, missing values, and anomalies.
#
# 2. **Handling Missing Data:** Employed techniques such as imputation or removal to address missing values, ensuring integrity in the dataset.
#
# 3. **Data Standardization:** Ensured uniformity in data format, such as date formats, categorical variables, and numerical scales.
#
# 4. **Removing Duplicates:** Eliminated duplicate entries to prevent redundancy and maintain data integrity.
#
# 5. **Data Transformation:** Converted data types, normalized values, and applied appropriate transformations for analysis readiness.
#
# By meticulously cleaning the dataset, I have prepared a high-quality foundation for subsequent data analysis and modeling tasks.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('amazon.csv',index_col=0)

# %%
df.head()
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                                      category  \
# product_id
# B07JW9H4J1  Computers&Accessories|Accessories&Peripherals|...
# B098NS6PVG  Computers&Accessories|Accessories&Peripherals|...
# B096MSW6CT  Computers&Accessories|Accessories&Peripherals|...
# B08HDJ86NZ  Computers&Accessories|Accessories&Peripherals|...
# B08CF3B7N1  Computers&Accessories|Accessories&Peripherals|...
#
#            discounted_price actual_price discount_percentage rating  \
# product_id
# B07JW9H4J1             ₹399       ₹1,099                 64%    4.2
# B098NS6PVG             ₹199         ₹349                 43%    4.0
# B096MSW6CT             ₹199       ₹1,899                 90%    3.9
# B08HDJ86NZ             ₹329         ₹699                 53%    4.2
# B08CF3B7N1             ₹154         ₹399                 61%    4.2
#
#            rating_count                                      about_product  \
# product_id
# B07JW9H4J1       24,269  High Compatibility : Compatible With iPhone 12...
# B098NS6PVG       43,994  Compatible with all Type C enabled devices, be...
# B096MSW6CT        7,928  【 Fast Charger& Data Sync】-With built-in safet...
# B08HDJ86NZ       94,363  The boAt Deuce USB 300 2 in 1 cable is compati...
# B08CF3B7N1       16,905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                                       user_id  \
# product_id
# B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                                     user_name  \
# product_id
# B07JW9H4J1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# B098NS6PVG  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# B096MSW6CT  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# B08HDJ86NZ  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# B08CF3B7N1  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                                     review_id  \
# product_id
# B07JW9H4J1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# B098NS6PVG  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# B096MSW6CT  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# B08HDJ86NZ  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# B08CF3B7N1  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                                  review_title  \
# product_id
# B07JW9H4J1  Satisfied,Charging is really fast,Value for mo...
# B098NS6PVG  A Good Braided Cable for Your Type C Device,Go...
# B096MSW6CT  Good speed for earlier versions,Good Product,W...
# B08HDJ86NZ  Good product,Good one,Nice,Really nice product...
# B08CF3B7N1  As good as original,Decent,Good one for second...
#
#                                                review_content  \
# product_id
# B07JW9H4J1  Looks durable Charging is fine tooNo complains...
# B098NS6PVG  I ordered this cable to connect my phone to An...
# B096MSW6CT  Not quite durable and sturdy,https://m.media-a...
# B08HDJ86NZ  Good product,long wire,Charges good,Nice,I bou...
# B08CF3B7N1  Bought this instead of original apple, does th...
#
#                                                      img_link  \
# product_id
# B07JW9H4J1  https://m.media-amazon.com/images/W/WEBP_40237...
# B098NS6PVG  https://m.media-amazon.com/images/W/WEBP_40237...
# B096MSW6CT  https://m.media-amazon.com/images/W/WEBP_40237...
# B08HDJ86NZ  https://m.media-amazon.com/images/I/41V5FtEWPk...
# B08CF3B7N1  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                                  product_link
# product_id
# B07JW9H4J1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# B098NS6PVG  https://www.amazon.in/Ambrane-Unbreakable-Char...
# B096MSW6CT  https://www.amazon.in/Sounce-iPhone-Charging-C...
# B08HDJ86NZ  https://www.amazon.in/Deuce-300-Resistant-Tang...
# B08CF3B7N1  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1465, 15)

# %%
df.columns
# Out:
# Index(['product_name', 'category', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'user_id', 'user_name', 'review_id', 'review_title', 'review_content',
#        'img_link', 'product_link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1465 entries, B07JW9H4J1 to B01486F4G6
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1465 non-null   object
#  1   category             1465 non-null   object
#  2   discounted_price     1465 non-null   object
#  3   actual_price         1465 non-null   object
#  4   discount_percentage  1465 non-null   object
#  5   rating               1465 non-null   object
#  6   rating_count         1463 non-null   object
#  7   about_product        1465 non-null   object
#  8   user_id              1465 non-null   object
#  9   user_name            1465 non-null   object
#  10  review_id            1465 non-null   object
#  11  review_title         1465 non-null   object
#  12  review_content       1465 non-null   object
#  13  img_link             1465 non-null   object
#  14  product_link         1465 non-null   object
# dtypes: object(15)
# memory usage: 183.1+ KB

# %%
df['discounted_price']=df['discounted_price'].str.replace('₹','')

# %%
df['discounted_price']=df['discounted_price'].str.replace(',','')

# %%
df['discounted_price']
# Out:
# product_id
# B07JW9H4J1     399
# B098NS6PVG     199
# B096MSW6CT     199
# B08HDJ86NZ     329
# B08CF3B7N1     154
#               ...
# B08L7J3T31     379
# B01M6453MB    2280
# B009P2LIL4    2219
# B00J5DYCCA    1399
# B01486F4G6    2863
# Name: discounted_price, Length: 1465, dtype: object

# %%
df['discounted_price']=df['discounted_price'].astype('float64')

# %%
df['discounted_price']
# Out:
# product_id
# B07JW9H4J1     399.0
# B098NS6PVG     199.0
# B096MSW6CT     199.0
# B08HDJ86NZ     329.0
# B08CF3B7N1     154.0
#                ...
# B08L7J3T31     379.0
# B01M6453MB    2280.0
# B009P2LIL4    2219.0
# B00J5DYCCA    1399.0
# B01486F4G6    2863.0
# Name: discounted_price, Length: 1465, dtype: float64

# %%
df['discount_percentage']=df['discount_percentage'].str.replace('%','').astype('float64')
df['discount_percentage']=df['discount_percentage']/100
df['discount_percentage']

# %%
df['actual_price']=df['actual_price'].str.replace('₹','').str.replace(',','')
df['actual_price']=df['actual_price'].astype('float64')

# %%
df['actual_price']
# Out:
# product_id
# B07JW9H4J1    1099.0
# B098NS6PVG     349.0
# B096MSW6CT    1899.0
# B08HDJ86NZ     699.0
# B08CF3B7N1     399.0
#                ...
# B08L7J3T31     919.0
# B01M6453MB    3045.0
# B009P2LIL4    3080.0
# B00J5DYCCA    1890.0
# B01486F4G6    3690.0
# Name: actual_price, Length: 1465, dtype: float64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df.query('rating=="|"')
# Out:
#                                                  product_name  \
# product_id
# B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                      category  \
# product_id
# B08L12N5H1  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
#
#            discounted_price actual_price discount_percentage rating  \
# product_id
# B08L12N5H1           ₹2,099       ₹2,499                 16%      |
#
#            rating_count                                      about_product  \
# product_id
# B08L12N5H1          992  No Installation is provided for this product|1...
#
#                                                       user_id  \
# product_id
# B08L12N5H1  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                                     user_name  \
# product_id
# B08L12N5H1  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                                     review_id  \
# product_id
# B08L12N5H1  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                                  review_title  \
# product_id
# B08L12N5H1  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                                review_content  \
# product_id
# B08L12N5H1  Does the job well,doesn't work on sand. though...
#
#                                                      img_link  \
# product_id
# B08L12N5H1  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                                  product_link
# product_id
# B08L12N5H1  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...

# %%
df['rating']=df['rating'].str.replace('|','4.0').astype('float64')

# %%
df['rating']
# Out:
# product_id
# B07JW9H4J1    4.2
# B098NS6PVG    4.0
# B096MSW6CT    3.9
# B08HDJ86NZ    4.2
# B08CF3B7N1    4.2
#              ...
# B08L7J3T31    4.0
# B01M6453MB    4.1
# B009P2LIL4    3.6
# B00J5DYCCA    4.0
# B01486F4G6    4.3
# Name: rating, Length: 1465, dtype: float64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
df.isna().sum()
# Out:
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
na=df[df.rating_count.isna()]
na
# Out:
#                                                  product_name  \
# product_id
# B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                                      category  \
# product_id
# B0B94JPY2N  Computers&Accessories|Accessories&Peripherals|...
# B0BQRJ3C47  Computers&Accessories|Accessories&Peripherals|...
#
#            discounted_price actual_price discount_percentage  rating  \
# product_id
# B0B94JPY2N             ₹199         ₹999                 80%     3.0
# B0BQRJ3C47             ₹249         ₹999                 75%     5.0
#
#            rating_count                                      about_product  \
# product_id
# B0B94JPY2N          NaN  USB C to C Cable: This cable has type C connec...
# B0BQRJ3C47          NaN  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                                  user_id    user_name      review_id  \
# product_id
# B0B94JPY2N  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# B0BQRJ3C47  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#                                             review_title  \
# product_id
# B0B94JPY2N  The cable works but is not 65W as advertised
# B0BQRJ3C47                               Awesome Product
#
#                                                review_content  \
# product_id
# B0B94JPY2N  I have a pd supported car charger and I bought...
# B0BQRJ3C47  Quick delivery.Awesome ProductPacking was good...
#
#                                                      img_link  \
# product_id
# B0B94JPY2N  https://m.media-amazon.com/images/W/WEBP_40237...
# B0BQRJ3C47  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                                  product_link
# product_id
# B0B94JPY2N  https://www.amazon.in/Amazon-Brand-Charging-Su...
# B0BQRJ3C47  https://www.amazon.in/REDTECH-Lightning-Certif...

# %%
df1=df[['product_name','category','discounted_price','actual_price','discount_percentage','rating','rating_count']].copy()
df1
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                       ...
# B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                      category  \
# product_id
# B07JW9H4J1  Computers&Accessories|Accessories&Peripherals|...
# B098NS6PVG  Computers&Accessories|Accessories&Peripherals|...
# B096MSW6CT  Computers&Accessories|Accessories&Peripherals|...
# B08HDJ86NZ  Computers&Accessories|Accessories&Peripherals|...
# B08CF3B7N1  Computers&Accessories|Accessories&Peripherals|...
# ...                                                       ...
# B08L7J3T31  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# B01M6453MB  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# B009P2LIL4  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# B00J5DYCCA  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# B01486F4G6  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1             399.0        1099.0                 0.64     4.2
# B098NS6PVG             199.0         349.0                 0.43     4.0
# B096MSW6CT             199.0        1899.0                 0.90     3.9
# B08HDJ86NZ             329.0         699.0                 0.53     4.2
# B08CF3B7N1             154.0         399.0                 0.61     4.2
# ...                      ...           ...                  ...     ...
# B08L7J3T31             379.0         919.0                 0.59     4.0
# B01M6453MB            2280.0        3045.0                 0.25     4.1
# B009P2LIL4            2219.0        3080.0                 0.28     3.6
# B00J5DYCCA            1399.0        1890.0                 0.26     4.0
# B01486F4G6            2863.0        3690.0                 0.22     4.3
#
#            rating_count
# product_id
# B07JW9H4J1       24,269
# B098NS6PVG       43,994
# B096MSW6CT        7,928
# B08HDJ86NZ       94,363
# B08CF3B7N1       16,905
# ...                 ...
# B08L7J3T31        1,090
# B01M6453MB        4,118
# B009P2LIL4          468
# B00J5DYCCA        8,031
# B01486F4G6        6,987
#
# [1465 rows x 7 columns]

# %%
split=df['category'].str.split('|',expand=True)

# %%
split
# Out:
#                                 0                           1  \
# product_id
# B07JW9H4J1  Computers&Accessories     Accessories&Peripherals
# B098NS6PVG  Computers&Accessories     Accessories&Peripherals
# B096MSW6CT  Computers&Accessories     Accessories&Peripherals
# B08HDJ86NZ  Computers&Accessories     Accessories&Peripherals
# B08CF3B7N1  Computers&Accessories     Accessories&Peripherals
# ...                           ...                         ...
# B08L7J3T31           Home&Kitchen      Kitchen&HomeAppliances
# B01M6453MB           Home&Kitchen      Kitchen&HomeAppliances
# B009P2LIL4           Home&Kitchen  Heating,Cooling&AirQuality
# B00J5DYCCA           Home&Kitchen  Heating,Cooling&AirQuality
# B01486F4G6           Home&Kitchen      Kitchen&HomeAppliances
#
#                                      2                         3          4  \
# product_id
# B07JW9H4J1          Cables&Accessories                    Cables  USBCables
# B098NS6PVG          Cables&Accessories                    Cables  USBCables
# B096MSW6CT          Cables&Accessories                    Cables  USBCables
# B08HDJ86NZ          Cables&Accessories                    Cables  USBCables
# B08CF3B7N1          Cables&Accessories                    Cables  USBCables
# ...                                ...                       ...        ...
# B08L7J3T31  WaterPurifiers&Accessories  WaterPurifierAccessories       None
# B01M6453MB      SmallKitchenAppliances         Rice&PastaCookers       None
# B009P2LIL4                 RoomHeaters            HeatConvectors       None
# B00J5DYCCA                        Fans               ExhaustFans       None
# B01486F4G6      SmallKitchenAppliances            SandwichMakers       None
#
#                5     6
# product_id
# B07JW9H4J1  None  None
# B098NS6PVG  None  None
# B096MSW6CT  None  None
# B08HDJ86NZ  None  None
# B08CF3B7N1  None  None
# ...          ...   ...
# B08L7J3T31  None  None
# B01M6453MB  None  None
# B009P2LIL4  None  None
# B00J5DYCCA  None  None
# B01486F4G6  None  None
#
# [1465 rows x 7 columns]

# %%
split=split.rename(columns={0:'category_1',1:'category_2',2:'category_3',3:'category_4'})
split
# Out:
#                        category_1                  category_2  \
# product_id
# B07JW9H4J1  Computers&Accessories     Accessories&Peripherals
# B098NS6PVG  Computers&Accessories     Accessories&Peripherals
# B096MSW6CT  Computers&Accessories     Accessories&Peripherals
# B08HDJ86NZ  Computers&Accessories     Accessories&Peripherals
# B08CF3B7N1  Computers&Accessories     Accessories&Peripherals
# ...                           ...                         ...
# B08L7J3T31           Home&Kitchen      Kitchen&HomeAppliances
# B01M6453MB           Home&Kitchen      Kitchen&HomeAppliances
# B009P2LIL4           Home&Kitchen  Heating,Cooling&AirQuality
# B00J5DYCCA           Home&Kitchen  Heating,Cooling&AirQuality
# B01486F4G6           Home&Kitchen      Kitchen&HomeAppliances
#
#                             category_3                category_4          4  \
# product_id
# B07JW9H4J1          Cables&Accessories                    Cables  USBCables
# B098NS6PVG          Cables&Accessories                    Cables  USBCables
# B096MSW6CT          Cables&Accessories                    Cables  USBCables
# B08HDJ86NZ          Cables&Accessories                    Cables  USBCables
# B08CF3B7N1          Cables&Accessories                    Cables  USBCables
# ...                                ...                       ...        ...
# B08L7J3T31  WaterPurifiers&Accessories  WaterPurifierAccessories       None
# B01M6453MB      SmallKitchenAppliances         Rice&PastaCookers       None
# B009P2LIL4                 RoomHeaters            HeatConvectors       None
# B00J5DYCCA                        Fans               ExhaustFans       None
# B01486F4G6      SmallKitchenAppliances            SandwichMakers       None
#
#                5     6
# product_id
# B07JW9H4J1  None  None
# B098NS6PVG  None  None
# B096MSW6CT  None  None
# B08HDJ86NZ  None  None
# B08CF3B7N1  None  None
# ...          ...   ...
# B08L7J3T31  None  None
# B01M6453MB  None  None
# B009P2LIL4  None  None
# B00J5DYCCA  None  None
# B01486F4G6  None  None
#
# [1465 rows x 7 columns]

# %%
df1['category_1']=split['category_1']

# %%
df1['category_2']=split['category_2']

# %%
df1['category_3']=split['category_3']

# %%
df1
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                       ...
# B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                      category  \
# product_id
# B07JW9H4J1  Computers&Accessories|Accessories&Peripherals|...
# B098NS6PVG  Computers&Accessories|Accessories&Peripherals|...
# B096MSW6CT  Computers&Accessories|Accessories&Peripherals|...
# B08HDJ86NZ  Computers&Accessories|Accessories&Peripherals|...
# B08CF3B7N1  Computers&Accessories|Accessories&Peripherals|...
# ...                                                       ...
# B08L7J3T31  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# B01M6453MB  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# B009P2LIL4  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# B00J5DYCCA  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# B01486F4G6  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1             399.0        1099.0                 0.64     4.2
# B098NS6PVG             199.0         349.0                 0.43     4.0
# B096MSW6CT             199.0        1899.0                 0.90     3.9
# B08HDJ86NZ             329.0         699.0                 0.53     4.2
# B08CF3B7N1             154.0         399.0                 0.61     4.2
# ...                      ...           ...                  ...     ...
# B08L7J3T31             379.0         919.0                 0.59     4.0
# B01M6453MB            2280.0        3045.0                 0.25     4.1
# B009P2LIL4            2219.0        3080.0                 0.28     3.6
# B00J5DYCCA            1399.0        1890.0                 0.26     4.0
# B01486F4G6            2863.0        3690.0                 0.22     4.3
#
#            rating_count             category_1                  category_2  \
# product_id
# B07JW9H4J1       24,269  Computers&Accessories     Accessories&Peripherals
# B098NS6PVG       43,994  Computers&Accessories     Accessories&Peripherals
# B096MSW6CT        7,928  Computers&Accessories     Accessories&Peripherals
# B08HDJ86NZ       94,363  Computers&Accessories     Accessories&Peripherals
# B08CF3B7N1       16,905  Computers&Accessories     Accessories&Peripherals
# ...                 ...                    ...                         ...
# B08L7J3T31        1,090           Home&Kitchen      Kitchen&HomeAppliances
# B01M6453MB        4,118           Home&Kitchen      Kitchen&HomeAppliances
# B009P2LIL4          468           Home&Kitchen  Heating,Cooling&AirQuality
# B00J5DYCCA        8,031           Home&Kitchen  Heating,Cooling&AirQuality
# B01486F4G6        6,987           Home&Kitchen      Kitchen&HomeAppliances
#
#                             category_3
# product_id
# B07JW9H4J1          Cables&Accessories
# B098NS6PVG          Cables&Accessories
# B096MSW6CT          Cables&Accessories
# B08HDJ86NZ          Cables&Accessories
# B08CF3B7N1          Cables&Accessories
# ...                                ...
# B08L7J3T31  WaterPurifiers&Accessories
# B01M6453MB      SmallKitchenAppliances
# B009P2LIL4                 RoomHeaters
# B00J5DYCCA                        Fans
# B01486F4G6      SmallKitchenAppliances
#
# [1465 rows x 10 columns]

# %%
df1.drop(columns='category',inplace=True)

# %%
df1
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                       ...
# B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1             399.0        1099.0                 0.64     4.2
# B098NS6PVG             199.0         349.0                 0.43     4.0
# B096MSW6CT             199.0        1899.0                 0.90     3.9
# B08HDJ86NZ             329.0         699.0                 0.53     4.2
# B08CF3B7N1             154.0         399.0                 0.61     4.2
# ...                      ...           ...                  ...     ...
# B08L7J3T31             379.0         919.0                 0.59     4.0
# B01M6453MB            2280.0        3045.0                 0.25     4.1
# B009P2LIL4            2219.0        3080.0                 0.28     3.6
# B00J5DYCCA            1399.0        1890.0                 0.26     4.0
# B01486F4G6            2863.0        3690.0                 0.22     4.3
#
#            rating_count             category_1                  category_2  \
# product_id
# B07JW9H4J1       24,269  Computers&Accessories     Accessories&Peripherals
# B098NS6PVG       43,994  Computers&Accessories     Accessories&Peripherals
# B096MSW6CT        7,928  Computers&Accessories     Accessories&Peripherals
# B08HDJ86NZ       94,363  Computers&Accessories     Accessories&Peripherals
# B08CF3B7N1       16,905  Computers&Accessories     Accessories&Peripherals
# ...                 ...                    ...                         ...
# B08L7J3T31        1,090           Home&Kitchen      Kitchen&HomeAppliances
# B01M6453MB        4,118           Home&Kitchen      Kitchen&HomeAppliances
# B009P2LIL4          468           Home&Kitchen  Heating,Cooling&AirQuality
# B00J5DYCCA        8,031           Home&Kitchen  Heating,Cooling&AirQuality
# B01486F4G6        6,987           Home&Kitchen      Kitchen&HomeAppliances
#
#                             category_3
# product_id
# B07JW9H4J1          Cables&Accessories
# B098NS6PVG          Cables&Accessories
# B096MSW6CT          Cables&Accessories
# B08HDJ86NZ          Cables&Accessories
# B08CF3B7N1          Cables&Accessories
# ...                                ...
# B08L7J3T31  WaterPurifiers&Accessories
# B01M6453MB      SmallKitchenAppliances
# B009P2LIL4                 RoomHeaters
# B00J5DYCCA                        Fans
# B01486F4G6      SmallKitchenAppliances
#
# [1465 rows x 9 columns]

# %%
df1.category_1.unique()
# Out:
# array(['Computers&Accessories', 'Electronics', 'MusicalInstruments',
#        'OfficeProducts', 'Home&Kitchen', 'HomeImprovement', 'Toys&Games',
#        'Car&Motorbike', 'Health&PersonalCare'], dtype=object)

# %%
df1['category_1']=df1['category_1'].str.replace('&',' & ')

# %%
df1['category_1']=df1['category_1'].str.replace('OfficeProducts','Office Products')

# %%
df1['category_1']=df1['category_1'].str.replace('HomeImprovements','Home Improvements')

# %%
df1['category_1'].unique()
# Out:
# array(['Computers   &   Accessories', 'Electronics', 'MusicalInstruments',
#        'Office Products', 'Home   &   Kitchen', 'HomeImprovement',
#        'Toys   &   Games', 'Car   &   Motorbike',
#        'Health   &   PersonalCare'], dtype=object)

# %%
df1['category_2'].unique()
# Out:
# array(['Accessories&Peripherals', 'NetworkingDevices',
#        'HomeTheater,TV&Video', 'HomeAudio', 'WearableTechnology',
#        'Mobiles&Accessories', 'Accessories',
#        'Headphones,Earbuds&Accessories', 'ExternalDevices&DataStorage',
#        'Microphones', 'GeneralPurposeBatteries&BatteryChargers',
#        'OfficePaperProducts', 'CraftMaterials', 'Cameras&Photography',
#        'OfficeElectronics', 'Printers,Inks&Accessories', 'Monitors',
#        'Components', 'Electrical', 'Arts&Crafts', 'PowerAccessories',
#        'Tablets', 'Laptops', 'Kitchen&HomeAppliances',
#        'Heating,Cooling&AirQuality', 'Kitchen&Dining',
#        'HomeStorage&Organization', 'CarAccessories',
#        'HomeMedicalSupplies&Equipment'], dtype=object)

# %%
df1['category_2']=df1['category_2'].str.replace('&',' & ')

# %%
df1['category_2'].unique()
# Out:
# array(['Accessories & Peripherals', 'NetworkingDevices',
#        'HomeTheater,TV & Video', 'HomeAudio', 'WearableTechnology',
#        'Mobiles & Accessories', 'Accessories',
#        'Headphones,Earbuds & Accessories',
#        'ExternalDevices & DataStorage', 'Microphones',
#        'GeneralPurposeBatteries & BatteryChargers', 'OfficePaperProducts',
#        'CraftMaterials', 'Cameras & Photography', 'OfficeElectronics',
#        'Printers,Inks & Accessories', 'Monitors', 'Components',
#        'Electrical', 'Arts & Crafts', 'PowerAccessories', 'Tablets',
#        'Laptops', 'Kitchen & HomeAppliances',
#        'Heating,Cooling & AirQuality', 'Kitchen & Dining',
#        'HomeStorage & Organization', 'CarAccessories',
#        'HomeMedicalSupplies & Equipment'], dtype=object)

# %%
df1.category_3.unique()
# Out:
# array(['Cables&Accessories', 'NetworkAdapters', 'Accessories',
#        'Televisions', 'Projectors', 'SatelliteEquipment',
#        'MediaStreamingDevices', 'AVReceivers&Amplifiers', 'Speakers',
#        'SmartWatches', 'MobileAccessories', 'Smartphones&BasicMobiles',
#        'MemoryCards', 'Headphones', 'LaptopAccessories', 'Adapters',
#        'PenDrives', 'Keyboards,Mice&InputDevices', 'Condenser',
#        'DisposableBatteries', 'Paper', 'Scrapbooking',
#        'ExternalHardDisks', 'VideoCameras', 'Calculators',
#        'Repeaters&Extenders', 'Inks,Toners&Cartridges',
#        'PCGamingPeripherals', 'PaintingMaterials', 'HardDiskBags',
#        'Flashes', None, 'Routers', 'RechargeableBatteries', 'USBGadgets',
#        'SecurityCameras', 'TabletAccessories', 'USBHubs',
#        'Audio&VideoAccessories', 'ExternalMemoryCardReaders', 'Memory',
#        'UninterruptedPowerSupplies', 'Cases', 'Adapters&Multi-Outlets',
#        'InternalSolidStateDrives', 'DataCards&Dongles',
#        'DrawingMaterials', 'InternalHardDrives', 'Printers', 'Earpads',
#        'Drawing&PaintingSupplies', 'ExternalSolidStateDrives',
#        'SurgeProtectors', 'CordManagement', 'HardDriveAccessories',
#        'TraditionalLaptops', 'SmallKitchenAppliances', 'RoomHeaters',
#        'Vacuum,Cleaning&Ironing', 'KitchenTools', 'WaterHeaters&Geysers',
#        'LaundryOrganization', 'Fans', 'Coffee,Tea&Espresso',
#        'WaterPurifiers&Accessories', 'InteriorAccessories',
#        'AirPurifiers', 'SewingMachines&Accessories', 'HealthMonitors',
#        'Humidifiers', 'AirConditioners', 'Parts&Accessories'],
#       dtype=object)

# %%
df1['category_3']=df1['category_3'].str.replace('&',' & ')

# %%
df1.category_3.unique()
# Out:
# array(['Cables & Accessories', 'NetworkAdapters', 'Accessories',
#        'Televisions', 'Projectors', 'SatelliteEquipment',
#        'MediaStreamingDevices', 'AVReceivers & Amplifiers', 'Speakers',
#        'SmartWatches', 'MobileAccessories', 'Smartphones & BasicMobiles',
#        'MemoryCards', 'Headphones', 'LaptopAccessories', 'Adapters',
#        'PenDrives', 'Keyboards,Mice & InputDevices', 'Condenser',
#        'DisposableBatteries', 'Paper', 'Scrapbooking',
#        'ExternalHardDisks', 'VideoCameras', 'Calculators',
#        'Repeaters & Extenders', 'Inks,Toners & Cartridges',
#        'PCGamingPeripherals', 'PaintingMaterials', 'HardDiskBags',
#        'Flashes', None, 'Routers', 'RechargeableBatteries', 'USBGadgets',
#        'SecurityCameras', 'TabletAccessories', 'USBHubs',
#        'Audio & VideoAccessories', 'ExternalMemoryCardReaders', 'Memory',
#        'UninterruptedPowerSupplies', 'Cases', 'Adapters & Multi-Outlets',
#        'InternalSolidStateDrives', 'DataCards & Dongles',
#        'DrawingMaterials', 'InternalHardDrives', 'Printers', 'Earpads',
#        'Drawing & PaintingSupplies', 'ExternalSolidStateDrives',
#        'SurgeProtectors', 'CordManagement', 'HardDriveAccessories',
#        'TraditionalLaptops', 'SmallKitchenAppliances', 'RoomHeaters',
#        'Vacuum,Cleaning & Ironing', 'KitchenTools',
#        'WaterHeaters & Geysers', 'LaundryOrganization', 'Fans',
#        'Coffee,Tea & Espresso', 'WaterPurifiers & Accessories',
#        'InteriorAccessories', 'AirPurifiers',
#        'SewingMachines & Accessories', 'HealthMonitors', 'Humidifiers',
#        'AirConditioners', 'Parts & Accessories'], dtype=object)

# %%
df1['category_1'].value_counts()
# Out:
# category_1
# Electronics                    526
# Computers   &   Accessories    453
# Home   &   Kitchen             448
# Office Products                 31
# MusicalInstruments               2
# HomeImprovement                  2
# Toys   &   Games                 1
# Car   &   Motorbike              1
# Health   &   PersonalCare        1
# Name: count, dtype: int64

# %%
df1['category_2'].value_counts()
# Out:
# category_2
# Accessories & Peripherals                    381
# Kitchen & HomeAppliances                     308
# HomeTheater,TV & Video                       162
# Mobiles & Accessories                        161
# Heating,Cooling & AirQuality                 116
# WearableTechnology                            76
# Headphones,Earbuds & Accessories              66
# NetworkingDevices                             34
# OfficePaperProducts                           27
# ExternalDevices & DataStorage                 18
# Cameras & Photography                         16
# HomeStorage & Organization                    16
# HomeAudio                                     16
# GeneralPurposeBatteries & BatteryChargers     14
# Accessories                                   14
# Printers,Inks & Accessories                   11
# CraftMaterials                                 7
# Components                                     5
# OfficeElectronics                              4
# Electrical                                     2
# Monitors                                       2
# Microphones                                    2
# Arts & Crafts                                  1
# PowerAccessories                               1
# Tablets                                        1
# Laptops                                        1
# Kitchen & Dining                               1
# CarAccessories                                 1
# HomeMedicalSupplies & Equipment                1
# Name: count, dtype: int64

# %%
df1['category_3'].value_counts()
# Out:
# category_3
# Cables & Accessories         240
# SmallKitchenAppliances       181
# Accessories                   97
# MobileAccessories             84
# Vacuum,Cleaning & Ironing     82
#                             ...
# Memory                         1
# ExternalMemoryCardReaders      1
# VideoCameras                   1
# Flashes                        1
# Parts & Accessories            1
# Name: count, Length: 71, dtype: int64

# %%
rating_score=[]

for score in df1['rating']:
    if   score <2.0 : rating_score.append('Poor')
    elif score <3.0 : rating_score.append('Below Average')
    elif score <4.0 : rating_score.append('Average')
    elif score <5.0 : rating_score.append('Above Average')
    elif score ==5.0: rating_score.append('Excellent')

# %%
df1['rating_score']=rating_score

# %%
df1['rating_score'] =df1['rating_score'].astype('category')

# %%
df1['rating_score']= df1['rating_score'].cat.reorder_categories(['Below Average', 'Average', 'Above Average', 'Excellent'],ordered=True)

# %%
df1['difference_price']= df1['actual_price']-df1['discounted_price']

# %%
df1.head()
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1             399.0        1099.0                 0.64     4.2
# B098NS6PVG             199.0         349.0                 0.43     4.0
# B096MSW6CT             199.0        1899.0                 0.90     3.9
# B08HDJ86NZ             329.0         699.0                 0.53     4.2
# B08CF3B7N1             154.0         399.0                 0.61     4.2
#
#            rating_count                   category_1  \
# product_id
# B07JW9H4J1       24,269  Computers   &   Accessories
# B098NS6PVG       43,994  Computers   &   Accessories
# B096MSW6CT        7,928  Computers   &   Accessories
# B08HDJ86NZ       94,363  Computers   &   Accessories
# B08CF3B7N1       16,905  Computers   &   Accessories
#
#                            category_2            category_3   rating_score  \
# product_id
# B07JW9H4J1  Accessories & Peripherals  Cables & Accessories  Above Average
# B098NS6PVG  Accessories & Peripherals  Cables & Accessories  Above Average
# B096MSW6CT  Accessories & Peripherals  Cables & Accessories        Average
# B08HDJ86NZ  Accessories & Peripherals  Cables & Accessories  Above Average
# B08CF3B7N1  Accessories & Peripherals  Cables & Accessories  Above Average
#
#             difference_price
# product_id
# B07JW9H4J1             700.0
# B098NS6PVG             150.0
# B096MSW6CT            1700.0
# B08HDJ86NZ             370.0
# B08CF3B7N1             245.0

# %%
reviewers=df[['user_id','user_name']]
reviewers
# Out:
#                                                       user_id  \
# product_id
# B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                       ...
# B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# B009P2LIL4  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                                     user_name
# product_id
# B07JW9H4J1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# B098NS6PVG  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# B096MSW6CT  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# B08HDJ86NZ  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# B08CF3B7N1  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                       ...
# B08L7J3T31  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# B01M6453MB  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# B009P2LIL4  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# B00J5DYCCA  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# B01486F4G6  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
# [1465 rows x 2 columns]

# %%
reviewer_id_split= reviewers['user_id'].str.split(',',expand=False)
reviewer_id_split
# Out:
# product_id
# B07JW9H4J1    [AG3D6O4STAQKAY2UVGEUV46KN35Q, AHMY5CWJMMK5BJR...
# B098NS6PVG    [AECPFYFQVRUWC3KGNLJIOREFP5LQ, AGYYVPDD7YG7FYN...
# B096MSW6CT    [AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA, AESFLDV2PT363T2...
# B08HDJ86NZ    [AEWAZDZZJLQUYVOVGBEUKSLXHQ5A, AG5HTSFRRE6NL3M...
# B08CF3B7N1    [AE3Q6KSUK5P75D5HFYHCRAOLODSA, AFUGIFH5ZAFXRDS...
#                                     ...
# B08L7J3T31    [AHITFY6AHALOFOHOZEOC6XBP4FEA, AFRABBODZJZQB6Z...
# B01M6453MB    [AFG5FM3NEMOL6BNFRV2NK5FNJCHQ, AGEINTRN6Z563RM...
# B009P2LIL4    [AGVPWCMAHYQWJOQKMUJN4DW3KM5Q, AF4Q3E66MY4SR7Y...
# B00J5DYCCA    [AF2JQCLSCY3QJATWUNNHUSVUPNQQ, AFDMLUXC5LS5RXD...
# B01486F4G6    [AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA, AG7QNJ2SCS5VS5V...
# Name: user_id, Length: 1465, dtype: object

# %%
reviewer_id_exp=reviewer_id_split.explode()
reviewer_id_clean=reviewer_id_exp.reset_index(drop=True)
reviewer_id_clean
# Out:
# 0        AG3D6O4STAQKAY2UVGEUV46KN35Q
# 1        AHMY5CWJMMK5BJRBBSNLYT3ONILA
# 2        AHCTC6ULH4XB6YHDY6PCH2R772LQ
# 3        AGYHHIERNXKA6P5T7CZLXKVPT7IQ
# 4        AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q
#                      ...
# 11498    AHXCDNSXAESERITAFELQABFVNLCA
# 11499    AGRZD6CHLCUNOLMMIMIHUCG7PIFA
# 11500    AFQZVGSOSOJHKFQQMCEI4725QEKQ
# 11501    AEALVGXXIP46OZVXKRUXSDWZJMEA
# 11502    AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ
# Name: user_id, Length: 11503, dtype: object

# %%
reviewer_name_split=reviewers['user_name'].str.split(',',expand=False)
reviewer_name_split
# Out:
# product_id
# B07JW9H4J1    [Manav, Adarsh gupta, Sundeep, S.Sayeed Ahmed,...
# B098NS6PVG    [ArdKn, Nirbhay kumar, Sagar Viswanathan, Asp,...
# B096MSW6CT    [Kunal, Himanshu, viswanath, sai niharka, saqi...
# B08HDJ86NZ    [Omkar dhale, JD, HEMALATHA, Ajwadh a., amar s...
# B08CF3B7N1    [rahuls6099, Swasat Borah, Ajay Wadke, Pranali...
#                                     ...
# B08L7J3T31    [Prabha ds, Raghuram bk, Real Deal, Amazon Cus...
# B01M6453MB    [Manu Bhai, Naveenpittu, Evatira Sangma, JAGAN...
# B009P2LIL4    [Nehal Desai, Danish Parwez, Amazon Customer, ...
# B00J5DYCCA    [Shubham Dubey, E.GURUBARAN, Mayank S., eusuf ...
# B01486F4G6    [Rajib, Ajay B, Vikas Kahol, PARDEEP, Anindya ...
# Name: user_name, Length: 1465, dtype: object

# %%
reviewer_name_exp=reviewer_name_split.explode()
reviewer_name_clean=reviewer_name_exp.reset_index(drop=True)
reviewer_name_clean
# Out:
# 0                   Manav
# 1            Adarsh gupta
# 2                 Sundeep
# 3          S.Sayeed Ahmed
# 4          jaspreet singh
#                ...
# 11510             PARDEEP
# 11511    Anindya Pramanik
# 11512         Vikas Singh
# 11513     Harshada Pimple
# 11514              Saw a.
# Name: user_name, Length: 11515, dtype: object

# %%
df21= pd.DataFrame(data=reviewer_id_clean)
df22= pd.DataFrame(data=reviewer_name_clean)

# %%
df2=pd.merge(df21,df22,left_index=True,right_index=True)
df2
# Out:
#                             user_id          user_name
# 0      AG3D6O4STAQKAY2UVGEUV46KN35Q              Manav
# 1      AHMY5CWJMMK5BJRBBSNLYT3ONILA       Adarsh gupta
# 2      AHCTC6ULH4XB6YHDY6PCH2R772LQ            Sundeep
# 3      AGYHHIERNXKA6P5T7CZLXKVPT7IQ     S.Sayeed Ahmed
# 4      AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q     jaspreet singh
# ...                             ...                ...
# 11498  AHXCDNSXAESERITAFELQABFVNLCA  BATTU SURESHKUMAR
# 11499  AGRZD6CHLCUNOLMMIMIHUCG7PIFA      Shubham Dubey
# 11500  AFQZVGSOSOJHKFQQMCEI4725QEKQ        E.GURUBARAN
# 11501  AEALVGXXIP46OZVXKRUXSDWZJMEA          Mayank S.
# 11502  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ         eusuf khan
#
# [11503 rows x 2 columns]
